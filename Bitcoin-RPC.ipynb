# %% [markdown]
# # Bitcoin RPC

# %% [markdown]
# ## Make Connection to Bitcoin Core

# %%
from bitcoinrpc.authproxy import AuthServiceProxy, JSONRPCException
from pprint import pprint

# https://github.com/bitcoin/bitcoin/blob/master/share/rpcauth/rpcauth.py
# pass in a username, and use the username and add :
# rpcauth=rpcauth=rag:9a6ab8dbd6a2bf5b480c2130974dcac1$c0f610a83b5a3cd1b25aca115691295a7d44c3cbb2130991a21251f3a34b6576
# rpc_user rpc_auth are set in the bitcoin.conf file
rpc_connection = AuthServiceProxy("http://%s:%s@127.0.0.1:8332"%("rag","fmo4HMWg7xNc20w8eEwgzIvVRLx75WDwFQn9nMeMqdg="))
best_block_hash = rpc_connection.getbestblockhash()

# %% [markdown]
# ## Get wallet once only (2nd time will give error)

# %%
# wallet_info = rpc_connection.loadwallet("testwallet") # uncomment to run when you load this jupyter notebook

# %%
# batch support : print timestamps of blocks 0 to 7 in 2 RPC round-trips:
commands = [ [ "getblockhash", height] for height in range(7) ]
block_hashes = rpc_connection.batch_(commands)
blocks = rpc_connection.batch_([ [ "getblock", h ] for h in block_hashes ])
block_times = [ block["time"] for block in blocks ]

# %%
block_count = rpc_connection.getblockcount()
print("Block Count:", block_count)
# Out:
# Block Count: 101

# %% [markdown]
# ## List UTXOs

# %%
utxos = rpc_connection.listunspent()
print("Utxos: ")
print("-----")
pprint(utxos)
# Out:
# Utxos:
# -----
# [{'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'amount': Decimal('50.00000000'),
#   'confirmations': 101,
#   'desc': "wpkh([28628bd2/84'/1'/0'/0/0]03f3f15d4dc5e9cee338b77add5c6b2eb86e449d468f97a952946ef5abfe0d445e)#gc58v9tt",
#   'label': '',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'safe': True,
#   'scriptPubKey': '001416d33353a60a25cb164caf3e88aaa057894f04e5',
#   'solvable': True,
#   'spendable': True,
#   'txid': 'e864ff630415ae2ab0534661d9d9197912c1cc3a9b6a60a252608e309e708ec5',
#   'vout': 0}]

# %% [markdown]
# ### Block times

# %%
block_times
# Out:
# [1296688602,
#  1675177614,
#  1675177615,
#  1675177615,
#  1675177616,
#  1675177616,
#  1675177616]

# %%
# print list of transactions
track_address = "bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8"
tx_list = rpc_connection.listtransactions()
tx_list
# Out:
# [{'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'category': 'immature',
#   'amount': Decimal('50.00000000'),
#   'label': '',
#   'vout': 0,
#   'confirmations': 10,
#   'generated': True,
#   'blockhash': '4717a0a6ae16b89de05b9ae7c77a7dc21614bb1a3440cf5572fd37eb504f9a53',
#   'blockheight': 92,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'txid': 'dbeceee86cecfa31b9db61a8259c71c6b6a2504ae8feb7ee447fbe4838aaba3c',
#   'wtxid': 'd10f8f0837fff6584fe2909ae2e48d3774c917ad55681fcd2d69420b04324eb6',
#   'walletconflicts': [],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'bip125-replaceable': 'no'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'category': 'immature',
#   'amount': Decimal('50.00000000'),
#   'label': '',
#   'vout': 0,
#   'confirmations': 9,
#   'generated': True,
#   'blockhash': '5af38179171242fb045ccfc29ff300a30f6e6fdde2f57e271f688586544328c1',
#   'blockheight': 93,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'txid': '6d28ebc4e3a20e2f6efb61f2d64dfe2fd6a0b09cf623b00f5e4a1b01708ae0be',
#   'wtxid': '916a713a7e4b324da06673b758b9e63628dad1e48b81e08dc9bcd80695693f2b',
#   'walletconflicts': [],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'bip125-replaceable': 'no'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'category': 'immature',
#   'amount': Decimal('50.00000000'),
#   'label': '',
#   'vout': 0,
#   'confirmations': 8,
#   'generated': True,
#   'blockhash': '1058b75c4873c4b00117522172a0b24f8e98917112ac62769d924de8fb3d29c0',
#   'blockheight': 94,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'txid': 'eab0e5a35c91721206b99642464743ef6a431ecc06a84588925428d9229f851a',
#   'wtxid': 'c52040d77a28cd65fd5b229ab8cf0f7c6bcc034c49a3f16093419bd8a7a0e99d',
#   'walletconflicts': [],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'bip125-replaceable': 'no'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'category': 'immature',
#   'amount': Decimal('50.00000000'),
#   'label': '',
#   'vout': 0,
#   'confirmations': 7,
#   'generated': True,
#   'blockhash': '09e88324faeea7f9adc08f917f1933ddd57ba835838c38cf5903940972074081',
#   'blockheight': 95,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'txid': 'cee1d3daafadd276b4b3ba52ef9320219867068fb22465eed41f2f0e95eaee07',
#   'wtxid': 'dd18e709834e5eea76eb0ccabb279a085ce5833ad0c9e42aeba9c9fd1e334a0d',
#   'walletconflicts': [],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'bip125-replaceable': 'no'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'category': 'immature',
#   'amount': Decimal('50.00000000'),
#   'label': '',
#   'vout': 0,
#   'confirmations': 6,
#   'generated': True,
#   'blockhash': '0ce69c55810b0c8ee21a9254360406703783949f62ca979e15b64eb18271e606',
#   'blockheight': 96,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'txid': 'b55cf6a44aafae90b3ac6ae6048ac1cb23557931b829a59f3bcf9033feb2c5a8',
#   'wtxid': 'bf2d9a8fa628f450774ef133dd140223d49a3f2c8c50d574ec54b7f1f4d1d4de',
#   'walletconflicts': [],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'bip125-replaceable': 'no'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'category': 'immature',
#   'amount': Decimal('50.00000000'),
#   'label': '',
#   'vout': 0,
#   'confirmations': 5,
#   'generated': True,
#   'blockhash': '372ac4e71952c42dac834578bc6d6533f07d8d27e4b8e277639b67fdb5f326d3',
#   'blockheight': 97,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'txid': '8b36f83c31afe3e8fe532a4e3191f5573f46ad14bebd5808939ed0427eb2d0ca',
#   'wtxid': '23051c9824b537cb8a6c35a567dfecd8663ed1e7c0b86e0a50e94a72043fa225',
#   'walletconflicts': [],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'bip125-replaceable': 'no'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'category': 'immature',
#   'amount': Decimal('50.00000000'),
#   'label': '',
#   'vout': 0,
#   'confirmations': 4,
#   'generated': True,
#   'blockhash': '2cc4d156ba631795065742f20f1348346bf42aee472951f0c4d618d0c94c5185',
#   'blockheight': 98,
#   'blockindex': 0,
#   'blocktime': 1675177632,
#   'txid': '32af1a9f9a732deb535a3aa1e0e7d7c4c4a41becee5ba7ca056318c42d63f994',
#   'wtxid': 'edc1304eacc9df4c9ff23a16e5283d7695efd84d4ccf50483c1afbc24afc0ec9',
#   'walletconflicts': [],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'bip125-replaceable': 'no'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'category': 'immature',
#   'amount': Decimal('50.00000000'),
#   'label': '',
#   'vout': 0,
#   'confirmations': 3,
#   'generated': True,
#   'blockhash': '01293cd05001a8dc0334b545809da93c943754f0b0d3239b2615f591678c5e6a',
#   'blockheight': 99,
#   'blockindex': 0,
#   'blocktime': 1675177632,
#   'txid': 'b7a4b23c8df499ba0ede7aa4a305825046e764b70618390bcffcc732de2e51b2',
#   'wtxid': 'f24e07c287168c47a1fb8b46f005751446a2f37db9b1fdb717ffc0038f4ce439',
#   'walletconflicts': [],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'bip125-replaceable': 'no'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'category': 'immature',
#   'amount': Decimal('50.00000000'),
#   'label': '',
#   'vout': 0,
#   'confirmations': 2,
#   'generated': True,
#   'blockhash': '3e17127391d5c45d18a46ce03b1dd50cbc78b46741d7d5478035adf1f1f80701',
#   'blockheight': 100,
#   'blockindex': 0,
#   'blocktime': 1675177632,
#   'txid': '08499287b78e84a32269c95fe0b3cb3c09a1b830ee53c2b95c818aacea62e10d',
#   'wtxid': '0cf0f7da69204f4e915727da1b491482ebe6dd7d8328af1da8f82646ea5d5bdc',
#   'walletconflicts': [],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'bip125-replaceable': 'no'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'category': 'immature',
#   'amount': Decimal('50.00000000'),
#   'label': '',
#   'vout': 0,
#   'confirmations': 1,
#   'generated': True,
#   'blockhash': '75ba79059ddde2040a7a94a5e8baee41f6ba75ae34a6a146ca85135caf2f7084',
#   'blockheight': 101,
#   'blockindex': 0,
#   'blocktime': 1675177632,
#   'txid': 'cc7f158f8759188761bfda1229c66e75dc185559beda9bdb3e9128dd779580a5',
#   'wtxid': '33bbe8324dd16fc6151baf0af5099dc3a6804d16f3c2e36f5c6d80a6ed7f14cf',
#   'walletconflicts': [],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'bip125-replaceable': 'no'}]

# %%
address_tx_list = []
for tx in tx_list:
    if tx['address'] == track_address:
        address_tx_list.append(tx)

pprint(address_tx_list)
# Out:
# [{'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'amount': Decimal('50.00000000'),
#   'bip125-replaceable': 'no',
#   'blockhash': '4717a0a6ae16b89de05b9ae7c77a7dc21614bb1a3440cf5572fd37eb504f9a53',
#   'blockheight': 92,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'category': 'immature',
#   'confirmations': 10,
#   'generated': True,
#   'label': '',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'txid': 'dbeceee86cecfa31b9db61a8259c71c6b6a2504ae8feb7ee447fbe4838aaba3c',
#   'vout': 0,
#   'walletconflicts': [],
#   'wtxid': 'd10f8f0837fff6584fe2909ae2e48d3774c917ad55681fcd2d69420b04324eb6'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'amount': Decimal('50.00000000'),
#   'bip125-replaceable': 'no',
#   'blockhash': '5af38179171242fb045ccfc29ff300a30f6e6fdde2f57e271f688586544328c1',
#   'blockheight': 93,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'category': 'immature',
#   'confirmations': 9,
#   'generated': True,
#   'label': '',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'txid': '6d28ebc4e3a20e2f6efb61f2d64dfe2fd6a0b09cf623b00f5e4a1b01708ae0be',
#   'vout': 0,
#   'walletconflicts': [],
#   'wtxid': '916a713a7e4b324da06673b758b9e63628dad1e48b81e08dc9bcd80695693f2b'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'amount': Decimal('50.00000000'),
#   'bip125-replaceable': 'no',
#   'blockhash': '1058b75c4873c4b00117522172a0b24f8e98917112ac62769d924de8fb3d29c0',
#   'blockheight': 94,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'category': 'immature',
#   'confirmations': 8,
#   'generated': True,
#   'label': '',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'txid': 'eab0e5a35c91721206b99642464743ef6a431ecc06a84588925428d9229f851a',
#   'vout': 0,
#   'walletconflicts': [],
#   'wtxid': 'c52040d77a28cd65fd5b229ab8cf0f7c6bcc034c49a3f16093419bd8a7a0e99d'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'amount': Decimal('50.00000000'),
#   'bip125-replaceable': 'no',
#   'blockhash': '09e88324faeea7f9adc08f917f1933ddd57ba835838c38cf5903940972074081',
#   'blockheight': 95,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'category': 'immature',
#   'confirmations': 7,
#   'generated': True,
#   'label': '',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'txid': 'cee1d3daafadd276b4b3ba52ef9320219867068fb22465eed41f2f0e95eaee07',
#   'vout': 0,
#   'walletconflicts': [],
#   'wtxid': 'dd18e709834e5eea76eb0ccabb279a085ce5833ad0c9e42aeba9c9fd1e334a0d'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'amount': Decimal('50.00000000'),
#   'bip125-replaceable': 'no',
#   'blockhash': '0ce69c55810b0c8ee21a9254360406703783949f62ca979e15b64eb18271e606',
#   'blockheight': 96,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'category': 'immature',
#   'confirmations': 6,
#   'generated': True,
#   'label': '',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'txid': 'b55cf6a44aafae90b3ac6ae6048ac1cb23557931b829a59f3bcf9033feb2c5a8',
#   'vout': 0,
#   'walletconflicts': [],
#   'wtxid': 'bf2d9a8fa628f450774ef133dd140223d49a3f2c8c50d574ec54b7f1f4d1d4de'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'amount': Decimal('50.00000000'),
#   'bip125-replaceable': 'no',
#   'blockhash': '372ac4e71952c42dac834578bc6d6533f07d8d27e4b8e277639b67fdb5f326d3',
#   'blockheight': 97,
#   'blockindex': 0,
#   'blocktime': 1675177631,
#   'category': 'immature',
#   'confirmations': 5,
#   'generated': True,
#   'label': '',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'txid': '8b36f83c31afe3e8fe532a4e3191f5573f46ad14bebd5808939ed0427eb2d0ca',
#   'vout': 0,
#   'walletconflicts': [],
#   'wtxid': '23051c9824b537cb8a6c35a567dfecd8663ed1e7c0b86e0a50e94a72043fa225'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'amount': Decimal('50.00000000'),
#   'bip125-replaceable': 'no',
#   'blockhash': '2cc4d156ba631795065742f20f1348346bf42aee472951f0c4d618d0c94c5185',
#   'blockheight': 98,
#   'blockindex': 0,
#   'blocktime': 1675177632,
#   'category': 'immature',
#   'confirmations': 4,
#   'generated': True,
#   'label': '',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'txid': '32af1a9f9a732deb535a3aa1e0e7d7c4c4a41becee5ba7ca056318c42d63f994',
#   'vout': 0,
#   'walletconflicts': [],
#   'wtxid': 'edc1304eacc9df4c9ff23a16e5283d7695efd84d4ccf50483c1afbc24afc0ec9'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'amount': Decimal('50.00000000'),
#   'bip125-replaceable': 'no',
#   'blockhash': '01293cd05001a8dc0334b545809da93c943754f0b0d3239b2615f591678c5e6a',
#   'blockheight': 99,
#   'blockindex': 0,
#   'blocktime': 1675177632,
#   'category': 'immature',
#   'confirmations': 3,
#   'generated': True,
#   'label': '',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'txid': 'b7a4b23c8df499ba0ede7aa4a305825046e764b70618390bcffcc732de2e51b2',
#   'vout': 0,
#   'walletconflicts': [],
#   'wtxid': 'f24e07c287168c47a1fb8b46f005751446a2f37db9b1fdb717ffc0038f4ce439'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'amount': Decimal('50.00000000'),
#   'bip125-replaceable': 'no',
#   'blockhash': '3e17127391d5c45d18a46ce03b1dd50cbc78b46741d7d5478035adf1f1f80701',
#   'blockheight': 100,
#   'blockindex': 0,
#   'blocktime': 1675177632,
#   'category': 'immature',
#   'confirmations': 2,
#   'generated': True,
#   'label': '',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'txid': '08499287b78e84a32269c95fe0b3cb3c09a1b830ee53c2b95c818aacea62e10d',
#   'vout': 0,
#   'walletconflicts': [],
#   'wtxid': '0cf0f7da69204f4e915727da1b491482ebe6dd7d8328af1da8f82646ea5d5bdc'},
#  {'address': 'bcrt1qzmfnx5axpgjuk9jv4ulg324q27y57p8976kjm8',
#   'amount': Decimal('50.00000000'),
#   'bip125-replaceable': 'no',
#   'blockhash': '75ba79059ddde2040a7a94a5e8baee41f6ba75ae34a6a146ca85135caf2f7084',
#   'blockheight': 101,
#   'blockindex': 0,
#   'blocktime': 1675177632,
#   'category': 'immature',
#   'confirmations': 1,
#   'generated': True,
#   'label': '',
#   'parent_descs': ["wpkh(tpubD6NzVbkrYhZ4YCybPaT3yQb7MZR8UYBwQbDjKKUbJbE8sZWeBdom4mC3YV6dMZZhKuztSUs3Q6r3apXqJYr5Rxsdq34buXBRbfTzwtKifU3/84'/1'/0'/0/*)#rhlgz3p9"],
#   'time': 1675177616,
#   'timereceived': 1675177616,
#   'txid': 'cc7f158f8759188761bfda1229c66e75dc185559beda9bdb3e9128dd779580a5',
#   'vout': 0,
#   'walletconflicts': [],
#   'wtxid': '33bbe8324dd16fc6151baf0af5099dc3a6804d16f3c2e36f5c6d80a6ed7f14cf'}]

# %% [markdown]
# ## Balance

# %%
balance = rpc_connection.getbalance()
balance
